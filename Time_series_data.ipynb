# %% [markdown]
# <a href="https://colab.research.google.com/github/bharath5293/data-handling/blob/main/Time_series_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# %%
data={
    "date":pd.to_datetime(["2022-1-5","2022-02-12","2022-3-1","2022-4-10","2022-5-1","2022-6-1","2022-7-16","2022-8-5","2022-9-1","2022-10-3",]),
    "value":[10,15,18,19,21,25,29,35,39,50]
}
df=pd.DataFrame(data)
df.set_index("date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["value"],marker='o')
plt.xlabel("date")
plt.ylabel("value")
plt.title("time series with trend")
plt.grid(True)
plt.show()

# %%
data={
    "date":pd.to_datetime(["2022-1-5","2022-02-12","2022-3-1","2022-4-10","2022-5-1","2022-6-1","2022-7-16","2022-8-5","2022-9-1","2022-10-3",]),
    "value":[100,150,128,200,180,160,170,300,202,310]
}
df=pd.DataFrame(data)
df.set_index("date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index,df["value"])
plt.xlabel("date")
plt.ylabel("value")
plt.title("time series with seasonality")
plt.grid(True)
plt.show()

# %%
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/sunspotarea.csv', parse_dates=['date'], index_col='date')
result = seasonal_decompose(data, model='additive', period=12)
fig, axes = plt.subplots(2, 2, figsize=(20, 8), dpi=100)
data.plot(ax=axes[0, 0], title='Original Data', legend=False)
result.trend.plot(ax=axes[0, 1], title='Trend Only', legend=False)
result.seasonal.plot(ax=axes[1, 1], title='Seasonal Only', legend=False)
result.resid.plot(ax=axes[1, 0], title='Residuals', legend=False)
plt.tight_layout()
plt.show()
